# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravan-Kumar-199/python_/blob/main/assesment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions:
# 1.Pre-defined
# 2.User-defined
#
# 1.Pre-defined functions - [The functions which are already available is known as Pre-defined functions]..
#
# 2.User-defined functions - [According to application requirement if we declare any function is known as User defined function]...

# %% [markdown]
# Pre-defined functions - {ex:-print(),input(),sum(),min(),max(),output()}

# %%
a=90
print(type(a))
# Out:
# <class 'int'>

# %%
b=9.8
print(type(b))
# Out:
# <class 'float'>

# %%
a=90
b=90.8
c=1
print(type(a)),print(type(b)),print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>
# (None, None, None)

# %% [markdown]
# User-defined functions - examples...

# %%
def show():
  print('hi')
  print("hello")
  print('welcome')
show()
print("thankyou")
# Out:
# hi
# hello
# welcome
# thankyou

# %%
def f1():
  print('hai')
def f2():
  print('hello')
print('thankyou')
# Out:
# thankyou

# %%
def f1():
  print('hai')
def f2():
  f1()
  print('hello')
f2()
print('thankyou')
# Out:
# hai
# hello
# thankyou
