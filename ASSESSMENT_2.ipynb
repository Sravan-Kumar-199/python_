# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravan-Kumar-199/python_/blob/main/2_assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arthematic Operations
#
# Addition

# %%
8+9
# Out:
# 17

# %%
a=7
b=9
a+b
# Out:
# 16

# %%
a=9
h=9
c=a+h
print("addition:",c)
# Out:
# addition: 18

# %% [markdown]
# Subraction

# %%
8-5
# Out:
# 3

# %%
a=8
s=3
a-s
# Out:
# 5

# %%
b=15
g=5
d=b-g
print("subraction:",d)
# Out:
# subraction: 10

# %% [markdown]
# Multiplication

# %%
8*9
# Out:
# 72

# %%
a=9
b=6
a*b
# Out:
# 54

# %%
a=92
s=15
g=a*s
print("multiplication:",g)
# Out:
# multiplication: 1380

# %% [markdown]
# Division

# %%
7/2
# Out:
# 3.5

# %%
a=50
b=10
a/b
# Out:
# 5.0

# %%
a=150
b=25
c=a/b
print("divion:",c)
# Out:
# divion: 6.0

# %% [markdown]
# Floor Division

# %%
7//2
# Out:
# 3

# %%
a=105
b=2
a//b
# Out:
# 52

# %%
a=79
b=5
c=a//b
print("floordivision:",c)
# Out:
# floordivision: 15

# %% [markdown]
# Modulo Division

# %%
30%5
# Out:
# 0

# %%
a=25
b=3
a%b
# Out:
# 1

# %%
a=975
b=5
c=a%b
print("modulodivision:",c)
# Out:
# modulodivision: 0

# %% [markdown]
# Exponent/Power

# %%
71**2
# Out:
# 5041

# %%
a=70
b=5
a**b
# Out:
# 1680700000

# %%
a=15
b=5
c=a**b
print("exponent:",c)
# Out:
# exponent: 759375
