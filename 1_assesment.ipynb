# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravan-Kumar-199/python_/blob/main/1_assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=7
c=11
a+b+c
# Out:
# 23

# %%
a=7
b=6
c=a*b
print("multiplication:",c)
# Out:
# multiplication: 42

# %%
fname="sravan"
sname="royal"
fullname=fname+sname
print("welcome:",fullname)
# Out:
# welcome: sravanroyal
